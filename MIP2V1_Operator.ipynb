# %% [markdown]
# # OPERATOR
# Sona Regina Salsabila | Matematika

# %% [markdown]
# Operator = Simbol-simbol yang dapat digunakan untuk mengubah nilai dari satu variabel dengan melibatkan satu atau lebih variabel dan literal.
#
# Tipe-tipe operator
#
# 1. Operator Aritmatika
# 2. Operator Assignment
# 3. Operalor Pembanding
# 4. Operator Logika
# 5. Operator Membership

# %% [markdown]
# # Operator Aritmatika

# %% [markdown]
# Operator Aritmatika digunakan untuk melakukan operasi matematika yang umum.
#
# Macam-macam operator aritmatika:
#
#     +  : penjumlahan
#     -  : pengurangan
#     *  : perkalian
#     /  : pembagian
#     %  : modulus
#     ** : perpangkatan
#     //: pembagian dengan hasil pembulatan

# %%
#contoh penggunaan operator  aritmatika

#Penjumlahan 
print('Penjumlahan') 
print (2+2) 
#Pengurangan 
print('-'*20) 
print('Pengurangan') 
print (2-3) 
#Perkalian 
print('-'*20) 
print('Perkalian') 
print (2*3)
#Pembagian 
print('-'*20) 
print('Pembagian') 
print(2/3) 
#Modulus 
print('-'*20) 
print ('Modulus') 
print (2%3) 
#Perpangkatan 
print('-'*20) 
print('Perpangkatan') 
print (2**3)
#Pembagian Pembulatan Floring 
print('-'*20) 
print('Pembagian Pembulatan Floring ') 
print (3//2)
# Out:
# Penjumlahan
# 4
# --------------------
# Pengurangan
# -1
# --------------------
# Perkalian
# 6
# --------------------
# Pembagian
# 0.6666666666666666
# --------------------
# Modulus
# 2
# --------------------
# Perpangkatan
# 8
# --------------------
# Pembagian Pembulatan Floring
# 1

# %% [markdown]
# Latihan Operator 1

# %%
#Buatlah program penenerapan opetator aritmatika 
#dengan nilai-nilai yang berbeda dari contoh di atas

#Penjumlahan 
print('Penjumlahan') 
print (7.5+8) 
#Pengurangan 
print('-'*20) 
print('Pengurangan') 
print (17-3) 
#Perkalian 
print('-'*20) 
print('Perkalian') 
print (12*3)
#Pembagian 
print('-'*20) 
print('Pembagian') 
print(150/25) 
#Modulus 
print('-'*20) 
print ('Modulus') 
print (13%3) 
#Perpangkatan 
print('-'*20) 
print('Perpangkatan') 
print (9**3)
#Pembagian Pembulatan Floring 
print('-'*20) 
print('Pembagian Pembulatan Floring ') 
print (55//2)
# Out:
# Penjumlahan
# 15.5
# --------------------
# Pengurangan
# 14
# --------------------
# Perkalian
# 36
# --------------------
# Pembagian
# 6.0
# --------------------
# Modulus
# 1
# --------------------
# Perpangkatan
# 729
# --------------------
# Pembagian Pembulatan Floring
# 27

# %% [markdown]
# # Operator Asignment

# %% [markdown]
# Operator assignment digunakan untuk menyimpan nilai menjadi suatu variabel
#
#     =   : contohnya x = 5      —> x = 5
#     +=  : contohnya x = x + 5  —> x += 5
#     -=  : contohnya x = x - 5  —> x -= 5
#     *=  : contohnya x = x * 5  —> x *= 5
#     /=  : contohnya x = x / 5  —> x /= 5
#     %=  : contohnya x = x % 5  —> x %= 5
#     **= : contohnya x = x ** 5 —> x **= 5
#     //= : contohnya x = x // 5 —> x //= 5

# %%
#Contoh penggunaan operator Assignment 

#Penjumlahan 
print('Penjumlahan') 
x=5 
x=x+5 
print(x) 
x=5
x+=3 
print(x) 
print('-'*20) 

#Pengurangan 
print ('Pengurangan') 
x=5 
x=x-5 
print(x) 
x=5
x-=3 
print(x) 
print('-'*20)

#Perkalian 
print('Peerkalian') 
x=5
X=x*5 
print(x) 
x=5 
x*=3 
print(x) 
print('-'*20) 

#Pembagian 
print('Pembagian') 
x=5 
x=x/5 
print(x) 
x=5 
x/=3 
print(x) 
print('-'*20)

#Modulus 
print('Modulus') 
x=5 
x=x%5 
print(x) 
x=5 
x%=3 
print(x) 
print('-'*20) 

#Pembagian Floring 
print('Pembagian Floring') 
x=5
x=x//5 
print(x) 
x=5 
x//=3 
print(x) 
print('-'*20)

#Perpangkatan 
print('Perpangkatan') 
x=5 
x=x**5 
print(x)
x=5 
x**=3 
print(x) 
print('-'*20)
# Out:
# Penjumlahan
# 10
# 8
# --------------------
# Pengurangan
# 0
# 2
# --------------------
# Peerkalian
# 5
# 15
# --------------------
# Pembagian
# 1.0
# 1.6666666666666667
# --------------------
# Modulus
# 0
# 2
# --------------------
# Pembagian Floring
# 1
# 1
# --------------------
# Perpangkatan
# 3125
# 125
# --------------------

# %% [markdown]
# Latihan Operator 2

# %%
# Buatlah program penenerapan operator assignment 
# dengan nilai-nilai yang berbeda dari contoh di atas

#Penjumlahan 
print('Penjumlahan') 
a=12 
x=a+5 
print(x) 
x=6
x+=3 
print(x) 
print('-'*20) 

#Pengurangan 
print('Pengurangan') 
a=25 
x=a-5 
print(x) 
x=9
x-=7 
print(x) 
print('-'*20)

#Perkalian 
print('Peerkalian') 
a=4
x=a*5 
print(x) 
x=5 
x*=7 
print(x) 
print('-'*20) 

#Pembagian 
print('Pembagian') 
a=14 
x=a/2 
print(x) 
x=25 
x/=5 
print(x) 
print('-'*20)

#Modulus 
print('Modulus') 
a=140 
x=a%20 
print(x) 
x=57 
x%=5 
print(x) 
print('-'*20) 

#Pembagian Floring 
print('Pembagian Floring') 
a=47
x=a//4 
print(x) 
x=78 
x//=8 
print(x) 
print('-'*20)

#Perpangkatan 
print('Perpangkatan') 
a=2 
x=a**8 
print(x)
x=3 
x**=5 
print(x) 
print('-'*20)
# Out:
# Penjumlahan
# 17
# 9
# --------------------
# Pengurangan
# 20
# 2
# --------------------
# Peerkalian
# 20
# 35
# --------------------
# Pembagian
# 7.0
# 5.0
# --------------------
# Modulus
# 0
# 2
# --------------------
# Pembagian Floring
# 11
# 9
# --------------------
# Perpangkatan
# 256
# 243
# --------------------

# %% [markdown]
# # Operator Pembanding

# %% [markdown]
# Operator pembanding digunakan untuk membandingkan 2 nilai atau variabel
#
# macam-macam operator pembanding:
#
#     == : samadengan
#     != : tidak samadengan
#     >  : lebih dari
#     <  : kurang dari
#     >= : lebih dari samadengan
#     <= : kurang dari samadengan

# %%
#Contoh penggunaan operator pembanding 

print(2==2) 
print(2!=2) 
print(2>2) 
print(2<2) 
print(2>=2) 
print(2<=2)
# Out:
# True
# False
# False
# False
# True
# True

# %% [markdown]
# Latihan Operator 3

# %%
# Buatlah program penenerapan operator pembanding 
#dengan nilai-nilai yang berbeda dari contoh di atas

print(10==4) 
print(6!=7) 
print(3>2) 
print(8<6) 
print(8>=8) 
print(12<=15)
# Out:
# False
# True
# True
# False
# True
# True

# %%
num=20
if num==20:
   print('iya')
   if num!=13:
      print('kamu!!')
if num>10:
    print('sudah')
    if num>=50:
        print('salah')
if num<25:
    print('bener')
    if num>=0:
        print('banget')
# Out:
# iya
# kamu!!
# sudah
# bener
# banget

# %% [markdown]
# # Operator Logika

# %% [markdown]
# Operator logika digunakan untuk mengkombinasikan statment-statment kondisional
#
# macam-macam operator logika:
#
#     and —> kondisi menjadi benar apabila semua statementnya benar
#     or  —> kondisi menjadi benar apabila salah satu statementnya ada yang benar
#     not —> membalik hasil dari benar ke salah dan salah ke benar

# %%
#Contoh penggunaan operator logika 

print(True and False) 
print(False or False) 
print(not False and True)
# Out:
# False
# False
# True

# %% [markdown]
# Latihan Operator 4

# %%
# Buatlah program penenerapan opetator logika 
# dengan nilai-nilai yang berbeda dari contoh di atas

a = 5 <= 3
b = 6 < 12

print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# True

# %% [markdown]
# # Operator Keanggotaan

# %% [markdown]
# Operator keanggotaan digunakan untuk menguji apakah urutan disajikan dalam suatu objek
#
# macam-macam operator keanggotaan:
#
#     in     —> return True ketika nilai tertentu dalam sebuah urutan ada
#     not in —> return True ketika nilai tertentu dalam sebuah urutan tidak ada

# %%
# Contoh penggunaan operator keanggotaan 

a=(1,2,3,4,5,6) 
b=2 
print(b in a) 

print('-'*20) 
a=(1,2,3,4,5,6) 
b=7 
print(b not in a)
# Out:
# True
# --------------------
# True

# %% [markdown]
# Latihan Operator 5

# %%
# Buatlah program penenerapan opetator keanggotaan/membership 
# dengan nilai-nilai yang berbeda dari contoh di atas

x=('aku','sedang','membaca')
y=('aku')
print(y in x) 

print('-'*20) 
x=('aku','sedang', 'membaca')
y=('buku')
print(y not in x)
# Out:
# True
# --------------------
# True
